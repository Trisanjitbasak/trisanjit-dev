# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np

# %%
iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['class'] = [iris.target_names[i] for i in iris.target]

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target   class
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
df["class"].unique()
# Out:
# array([np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')],
#       dtype=object)

# %%
reg = LogisticRegression()

# %%
X = df.drop(["target", "class"], axis=1)
y = df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
reg.predict(X_test)
# Out:
# array([2, 2, 1, 1, 2, 1, 2, 2, 2, 1, 0, 0, 2, 2, 0, 2, 1, 1, 1, 2, 1, 1,
#        0, 0, 2, 2, 0, 2, 1, 0])

# %%
print(round(reg.score(X_test, y_test)*100,2),"%")
# Out:
# 93.33 %

# %%
a = reg.predict([[5.1,3.4,1.5,0.2]])
species_name = np.array(['setosa','versicolor', 'virginica'])
print(species_name[a])
# Out:
# ['setosa']
# /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
